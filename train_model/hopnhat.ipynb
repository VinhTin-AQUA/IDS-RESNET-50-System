# %%
import pandas as pd

# %%
def process_csv(input_file, output_file):
    # Đọc tệp CSV
    df = pd.read_csv(input_file)
    
    # Giữ nguyên các dòng có nhãn BENIGN, MSSQL, LDAP, SYN
    labels_to_keep = ["BENIGN", "MSSQL", "LDAP", "Syn"]
    df_filtered = df[df['Label'].isin(labels_to_keep)]
    
    # Xử lý NetBIOS và Portmap (50% mỗi loại)
    netbios = df[df['Label'] == 'NetBIOS'].sample(frac=0.5, random_state=42)
    portmap = df[df['Label'] == 'Portmap'].sample(frac=0.5, random_state=42)
    netbios_portmap_merged = pd.concat([netbios, portmap])
    netbios_portmap_merged['Label'] = 'NetBIOS-Portmap'
    
    # Xử lý UDP và UDP-Lag (50% mỗi loại)
    udp = df[df['Label'] == 'UDP'].sample(frac=0.5, random_state=42)
    udp_lag = df[df['Label'] == 'UDPLag'].sample(frac=0.5, random_state=42)
    udp_merged = pd.concat([udp, udp_lag])
    udp_merged['Label'] = 'UDP-Combined'
    
    # Gộp tất cả lại
    final_df = pd.concat([df_filtered, netbios_portmap_merged, udp_merged])
    
    # Lưu ra tệp CSV mới
    final_df.to_csv(output_file, index=False)
    print(f"Tạo tệp {output_file} thành công!")

# Gọi hàm xử lý
process_csv('data/csv/cicddos_2019.csv', 'data/csv/cicddos_2019_6_labels.csv')
# Out:
# Tạo tệp data/csv/cicddos_2019_6_labels.csv thành công!

# %%
df = pd.read_csv('data/csv/cicddos_2019_6_labels.csv')
df['Label'].value_counts()
# Out:
# Label
# BENIGN             5000
# LDAP               5000
# MSSQL              5000
# Syn                5000
# NetBIOS-Portmap    5000
# UDP-Combined       5000
# Name: count, dtype: int64

# %%
selected_columns = ['Protocol', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 
                    'Fwd Packets Length Total', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 
                    'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 
                    'Bwd Packet Length Mean', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 
                    'Flow IAT Max', 'Flow IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Min', 
                    'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 
                    'Bwd Header Length', 'Bwd Packets/s', 'Packet Length Max', 'FIN Flag Count', 'SYN Flag Count', 
                    'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 
                    'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 
                    'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Init Fwd Win Bytes', 'Init Bwd Win Bytes', 
                    'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Std', 'Label']

# %%
df = pd.read_csv('data/csv/cicddos_2019_6_labels.csv')
df = df[df['Label'] == 'Syn']
df = df[selected_columns]

# %%
df.sample(10)
# Out:
#        Protocol  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 17690         6              1                  2                       0
# 17796         6             45                  2                       0
# 19344         6              2                  2                       0
# 18029         6       61120524                 10                       2
# 15631         6              1                  2                       0
# 15375         6            100                  2                       2
# 17535         6             49                  2                       0
# 18771         6             52                  2                       2
# 18267         6             48                  2                       0
# 17441         6            102                  2                       2
#
#        Fwd Packets Length Total  Fwd Packet Length Max  Fwd Packet Length Min  \
# 17690                      12.0                    6.0                    6.0
# 17796                      12.0                    6.0                    6.0
# 19344                      12.0                    6.0                    6.0
# 18029                      60.0                    6.0                    6.0
# 15631                      12.0                    6.0                    6.0
# 15375                      12.0                    6.0                    6.0
# 17535                      12.0                    6.0                    6.0
# 18771                      12.0                    6.0                    6.0
# 18267                      12.0                    6.0                    6.0
# 17441                      12.0                    6.0                    6.0
#
#        Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Min  \
# 17690                    0.0                    0.0                    0.0
# 17796                    0.0                    0.0                    0.0
# 19344                    0.0                    0.0                    0.0
# 18029                    0.0                    6.0                    6.0
# 15631                    0.0                    0.0                    0.0
# 15375                    0.0                    6.0                    6.0
# 17535                    0.0                    0.0                    0.0
# 18771                    0.0                    6.0                    6.0
# 18267                    0.0                    0.0                    0.0
# 17441                    0.0                    6.0                    6.0
#
#        ...  Bwd Avg Bulk Rate  Init Fwd Win Bytes  Init Bwd Win Bytes  \
# 17690  ...                  0                5840                  -1
# 17796  ...                  0                5840                  -1
# 19344  ...                  0                5840                  -1
# 18029  ...                  0                5840                   0
# 15631  ...                  0                5840                  -1
# 15375  ...                  0                5840                   0
# 17535  ...                  0                5840                  -1
# 18771  ...                  0                5840                   0
# 18267  ...                  0                5840                  -1
# 17441  ...                  0                5840                   0
#
#        Fwd Seg Size Min  Active Mean  Active Std  Active Max  Active Min  \
# 17690                20          0.0    0.000000         0.0         0.0
# 17796                20          0.0    0.000000         0.0         0.0
# 19344                20          0.0    0.000000         0.0         0.0
# 18029                20         34.0   57.157677       100.0         1.0
# 15631                20          0.0    0.000000         0.0         0.0
# 15375                20          0.0    0.000000         0.0         0.0
# 17535                20          0.0    0.000000         0.0         0.0
# 18771                20          0.0    0.000000         0.0         0.0
# 18267                20          0.0    0.000000         0.0         0.0
# 17441                20          0.0    0.000000         0.0         0.0
#
#            Idle Std  Label
# 17690  0.000000e+00    Syn
# 17796  0.000000e+00    Syn
# 19344  0.000000e+00    Syn
# 18029  6.986067e+06    Syn
# 15631  0.000000e+00    Syn
# 15375  0.000000e+00    Syn
# 17535  0.000000e+00    Syn
# 18771  0.000000e+00    Syn
# 18267  0.000000e+00    Syn
# 17441  0.000000e+00    Syn
#
# [10 rows x 50 columns]

# %%
selected_columns = ['Protocol', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 
                    'Fwd Packets Length Total', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 
                    'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 
                    'Bwd Packet Length Mean', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 
                    'Flow IAT Max', 'Flow IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Min', 
                    'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 
                    'Bwd Header Length', 'Bwd Packets/s', 'Packet Length Max', 'FIN Flag Count', 'SYN Flag Count', 
                    'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 
                    'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 
                    'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Init Fwd Win Bytes', 'Init Bwd Win Bytes', 
                    'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Std', 'Label']

syn_df = pd.read_csv('temp/actual_data/test_syn.csv')
syn_df = syn_df[syn_df['Label'] == 'Syn']
syn_df = syn_df[selected_columns]

# %%
syn_df.sample(10)
# Out:
#     Protocol  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 4          6   2.939425e+05                  0                       8
# 26         6   3.403366e+05                  0                       9
# 18         6   2.511711e+06                  0                      11
# 13         6   6.896995e+06                  0                      27
# 37         6   2.437576e+06                  0                      15
# 30         6   2.606082e+05                  0                      11
# 35         6   2.701449e+05                  0                      12
# 32         6   3.102679e+05                  0                      12
# 2          6   3.011408e+05                  0                       8
# 10         6   3.786376e+05                  0                       3
#
#     Fwd Packets Length Total  Fwd Packet Length Max  Fwd Packet Length Min  \
# 4                          0                    0.0                    0.0
# 26                         0                    0.0                    0.0
# 18                         0                    0.0                    0.0
# 13                         0                    0.0                    0.0
# 37                         0                    0.0                    0.0
# 30                         0                    0.0                    0.0
# 35                         0                    0.0                    0.0
# 32                         0                    0.0                    0.0
# 2                          0                    0.0                    0.0
# 10                         0                    0.0                    0.0
#
#     Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Min  ...  \
# 4                     0.0                   91.0                   60.0  ...
# 26                    0.0                   92.0                   60.0  ...
# 18                    0.0                   93.0                   60.0  ...
# 13                    0.0                   93.0                   60.0  ...
# 37                    0.0                   94.0                   60.0  ...
# 30                    0.0                   89.0                   60.0  ...
# 35                    0.0                   93.0                   60.0  ...
# 32                    0.0                   93.0                   60.0  ...
# 2                     0.0                   86.0                   60.0  ...
# 10                    0.0                   84.0                   60.0  ...
#
#     Bwd Avg Packets/Bulk  Init Fwd Win Bytes  Init Bwd Win Bytes  \
# 4                   8.00                   0                4988
# 26                  9.00                   0                1644
# 18                  5.50                   0                8270
# 13                  6.75                   0                8216
# 37                 12.00                   0                8385
# 30                 11.00                   0                4780
# 35                 12.00                   0                4983
# 32                 12.00                   0                5377
# 2                   8.00                   0                2936
# 10                  0.00                   0                4911
#
#     Fwd Seg Size Min   Active Mean  Active Std    Active Max    Active Min  \
# 4                  0  2.939425e+05         0.0  2.939425e+05  2.939425e+05
# 26                 0  3.403366e+05         0.0  3.403366e+05  3.403366e+05
# 18                 0  2.511711e+06         0.0  2.511711e+06  2.511711e+06
# 13                 0  6.896995e+06         0.0  6.896995e+06  6.896995e+06
# 37                 0  2.437576e+06         0.0  2.437576e+06  2.437576e+06
# 30                 0  2.606082e+05         0.0  2.606082e+05  2.606082e+05
# 35                 0  2.701449e+05         0.0  2.701449e+05  2.701449e+05
# 32                 0  3.102679e+05         0.0  3.102679e+05  3.102679e+05
# 2                  0  3.011408e+05         0.0  3.011408e+05  3.011408e+05
# 10                 0  3.786376e+05         0.0  3.786376e+05  3.786376e+05
#
#     Idle Std   Label
# 4        0.0  Unknow
# 26       0.0  Unknow
# 18       0.0  Unknow
# 13       0.0  Unknow
# 37       0.0  Unknow
# 30       0.0  Unknow
# 35       0.0  Unknow
# 32       0.0  Unknow
# 2        0.0  Unknow
# 10       0.0  Unknow
#
# [10 rows x 48 columns]
